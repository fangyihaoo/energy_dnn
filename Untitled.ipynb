# %%
import torch

# %%
err102 = torch.load("error102.pt",map_location=torch.device('cpu'))
err103 = torch.load("error103.pt",map_location=torch.device('cpu'))
err102fix = torch.load("error102fix.pt",map_location=torch.device('cpu'))
err103fix = torch.load("error103fix.pt",map_location=torch.device('cpu'))

# %%
import matplotlib.pyplot as plt

# %%
b = list(range(1, 302))

# %%
len(err102fix)
# Out:
# 301

# %%
plt.plot(b, err102, label = "Error 0.01", linestyle="-")
plt.plot(b, err103, label = "Error 0.001", linestyle="--")
plt.plot(b, err102fix, label = "Error 0.01 Fixed", linestyle="-.")
plt.plot(b, err103fix, label = "Error 0.001 Fixed", linestyle=":")
plt.legend()
plt.savefig('error.png')
